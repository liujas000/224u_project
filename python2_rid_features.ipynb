# %%
import en
import pickle
import numpy as np
# https://www.nodebox.net/code/index.php/Linguistics

# %%
data = pickle.load( open( "save.p", "rb" ) )

# %%
max_num = 0
for a in data:
    max_num = max(max_num, np.max(data[a]['indices']))
print(max_num)
# Out:
# 228418

# %%
rid_cats = ['abstraction', 'affection', 'aggression', 'anality', 'anxiety', 'ascent', 'brink-passage', 'chaos', 'cold', 'concreteness', 'consciousness alteration', 'depth', 'descent', 'diffusion', 'expressive behavior', 'fire', 'general-sensation', 'glory', 'hard', 'height', 'instrumental behavior', 'moral imperative', 'narcissism', 'odor', 'orality', 'order', 'passivity', 'positive affect', 'random movement', 'restraint', 'sadness', 'sex', 'social behavior', 'soft', 'sound', 'taste', 'temporal references', 'timelessness', 'touch', 'unknown', 'vision', 'voyage', 'water']
rid_dict = {}
for i, e in enumerate(rid_cats):
    rid_dict[e] = i
print(rid_dict)
print(len(rid_cats))
rid_cats[1], rid_cats[11]
# Out:
# {'random movement': 28, 'taste': 35, 'hard': 18, 'consciousness alteration': 10, 'height': 19, 'touch': 38, 'anality': 3, 'cold': 8, 'orality': 24, 'ascent': 5, 'sadness': 30, 'aggression': 2, 'voyage': 41, 'expressive behavior': 14, 'positive affect': 27, 'descent': 12, 'unknown': 39, 'chaos': 7, 'brink-passage': 6, 'instrumental behavior': 20, 'narcissism': 22, 'sound': 34, 'abstraction': 0, 'fire': 15, 'restraint': 29, 'odor': 23, 'water': 42, 'temporal references': 36, 'concreteness': 9, 'general-sensation': 16, 'moral imperative': 21, 'diffusion': 13, 'anxiety': 4, 'glory': 17, 'sex': 31, 'social behavior': 32, 'timelessness': 37, 'depth': 11, 'vision': 40, 'passivity': 26, 'soft': 33, 'order': 25, 'affection': 1}
# 43
# ('affection', 'depth')

# %%
# result = set()
# num = 0
# for artist in data:
#     num += 1
#     if num < 100:
#         pass
#     for lyric in data[artist]['lyrics']:
#         rid_feat(lyric)
#         num += 1
#         if num % 1000 == 0:
#             print num
# print len(result)

# %%
def rid_feat(lyric, ind, mat):
    result = mat[ind]
    summary = en.content.categorise(lyric)
    for category in summary:
        ind = rid_dict[category.name]
        result[ind] = category.count
    if np.sum(result) != 0 :
        result /= np.sum(result)
#     return result

# %%
NUM_LYRIC = 228419
NUM_FEAT = 43

rid_mat = np.zeros((NUM_LYRIC, NUM_FEAT))
num = 0
for artist in data:
    for i in range(len(data[artist]['lyrics'])):
        lyric = data[artist]['lyrics'][i]
        ind = data[artist]['indices'][i]
        rid_feat(lyric, ind, rid_mat)
        num += 1
        if num % 500 == 0:
            print(num)
np.save('data/rid_mat.npy', pos_mat)
# Out:
# 500
# 1000
# 1500
# 2000
# 2500
# 3000
# 3500
# 4000
# 4500
# 5000
# 5500
# 6000
# 6500
# 7000
# 7500
# 8000
# 8500
# 9000
# 9500
# 10000
# 10500
# 11000
# 11500
# 12000
# 12500
# 13000
# 13500
# 14000
# 14500
# 15000
# 15500
# 16000
# 16500
# 17000
# 17500
# 18000
# 18500
# 19000
# 19500
# 20000
# 20500
# 21000
# 21500
# 22000
# 22500
# 23000
# 23500
# 24000
# 24500
# 25000
# 25500
# 26000
# 26500
# 27000
# 27500
# 28000
# 28500
# 29000
# 29500
# 30000
# 30500
# 31000
# 31500
# 32000
# 32500
# 33000
# 33500
# 34000
# 34500
# 35000
# 35500
# 36000
# 36500
# 37000
# 37500
# 38000
# 38500
# 39000
# 39500
# 40000
# 40500
# 41000
# 41500
# 42000
# 42500
# 43000
# 43500
# 44000
# 44500
# 45000
# 45500
# 46000
# 46500
# 47000
# 47500
# 48000
# 48500
# 49000
# 49500
# 50000
# 50500
# 51000
# 51500
# 52000
# 52500
# 53000
# 53500
# 54000
# 54500
# 55000
# 55500
# 56000
# 56500
# 57000
# 57500
# 58000
# 58500
# 59000
# 59500
# 60000
# 60500
# 61000
# 61500
# 62000
# 62500
# 63000
# 63500
# ...

# %%
np.sum([data[a]['count'] for a in data])
# Out:
# 228419

# %% [markdown]
# ### Create the feature matrix

# %%
mat = np.zeros((NUM_LYRICS, NUM_FEATURES))
NUM_LYRICS = 228419
NUM_FEATURES = 43
num = 0
for artist in data:
    for i in range(len(data[artist]['lyrics'])):
        lyric = data[artist]['lyrics'][i]
        ind = data[artist]['indices'][i]
        rid_feat(lyric, ind, mat)
        num += 1
        if num % 500 == 0:
            print num
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-73-8ed4c4e53263> in <module>()
#       7         lyric = data[artist]['lyrics'][i]
#       8         ind = data[artist]['indices'][i]
# ----> 9         rid_feat(lyric, ind, mat)
#      10         num += 1
#      11         if num % 500 == 0:
#
# <ipython-input-67-ac6aaf19609a> in rid_feat(lyric, ind, mat)
#       4 def rid_feat(lyric, ind, mat):
#       5     result = mat[ind]
# ----> 6     summary = en.content.categorise(lyric)
#       7     for category in summary:
#       8         ind = rid_dict[category.name]
#
# /Users/jasonliu/Box Sync/SeniorYear/Spring/cs224u/project/en/__init__.pyc in categorise(self, str)
#     189
#     190     def categorise(self, str):
# --> 191         return rid.categorise(str)
#     192
#     193 number = number()
#
# ...

# %%
np.save('data/rid_mat.npy', rid_mat)
